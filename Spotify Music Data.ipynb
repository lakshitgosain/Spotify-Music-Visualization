# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data.csv')

# %%
data.rename(columns={'Unnamed: 0':'Id'},inplace=True)

# %%
data.head()
# Out:
#    Id  acousticness                                            artists  \
# 0   0         0.732                                     ['Dennis Day']
# 1   1         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 2   2         0.996                                 ['John McCormack']
# 3   3         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 4   4         0.957                                     ['Phil Regan']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.819       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 1         0.279       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 2         0.518       159507   0.203         0  5uNZnElqOS3W4fRmRYPk4T
# 3         0.279       831667   0.211         0  1SCWBjhk5WmXPxhDduD3HM
# 4         0.418       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.000000    7     0.160   -12.441     1
# ...

# %%
data.head()
# Out:
#    Id  acousticness                                            artists  \
# 0   0         0.732                                     ['Dennis Day']
# 1   1         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 2   2         0.996                                 ['John McCormack']
# 3   3         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 4   4         0.957                                     ['Phil Regan']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.819       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 1         0.279       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 2         0.518       159507   0.203         0  5uNZnElqOS3W4fRmRYPk4T
# 3         0.279       831667   0.211         0  1SCWBjhk5WmXPxhDduD3HM
# 4         0.418       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.000000    7     0.160   -12.441     1
# ...

# %%
df=data.copy()
df_genre=pd.read_csv('data_by_genres.csv')
df_artist=pd.read_csv('data_by_artist.csv')
df_year=pd.read_csv('data_by_year.csv')
df_wgenre=pd.read_csv('data_w_genres.csv')

# %%
df.head()
# Out:
#    Id  acousticness                                            artists  \
# 0   0         0.732                                     ['Dennis Day']
# 1   1         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 2   2         0.996                                 ['John McCormack']
# 3   3         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 4   4         0.957                                     ['Phil Regan']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.819       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 1         0.279       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 2         0.518       159507   0.203         0  5uNZnElqOS3W4fRmRYPk4T
# 3         0.279       831667   0.211         0  1SCWBjhk5WmXPxhDduD3HM
# 4         0.418       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.000000    7     0.160   -12.441     1
# ...

# %%
df_genre.head()
# Out:
#                    genres  acousticness  danceability   duration_ms    energy  \
# 0  21st century classical      0.983000      0.218500  1.496130e+05  0.018350
# 1                   432hz      0.485070      0.330000  1.059273e+06  0.463084
# 2                      []      0.686395      0.516830  2.305397e+05  0.397491
# 3              a cappella      0.666036      0.576732  1.961439e+05  0.334535
# 4                abstract      0.352395      0.489100  3.429772e+05  0.509300
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.874000  0.112800 -37.256000     0.038750   69.526500  0.062900
# 1          0.480393  0.118862 -17.099000     0.086288  125.227125  0.217675
# 2          0.202883  0.221324 -12.773475     0.109871  111.933224  0.513905
# 3          0.028486  0.128292 -13.011177     0.106782  112.461108  0.502521
# 4          0.788033  0.122317 -13.812100     0.044157  124.176500  0.354130
#
#    popularity  key  mode
# ...

# %%
df_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2617 entries, 0 to 2616
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            2617 non-null   object
#  1   acousticness      2617 non-null   float64
#  2   danceability      2617 non-null   float64
#  3   duration_ms       2617 non-null   float64
#  4   energy            2617 non-null   float64
#  5   instrumentalness  2617 non-null   float64
#  6   liveness          2617 non-null   float64
#  7   loudness          2617 non-null   float64
#  8   speechiness       2617 non-null   float64
#  9   tempo             2617 non-null   float64
#  10  valence           2617 non-null   float64
#  11  popularity        2617 non-null   float64
#  12  key               2617 non-null   int64
#  13  mode              2617 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 286.4+ KB

# %%
df_genre['genres'].unique().tolist()
# Out:
# ['21st century classical',
#  '432hz',
#  '[]',
#  'a cappella',
#  'abstract',
#  'abstract beats',
#  'abstract hip hop',
#  'abstract idm',
#  'accordeon',
#  'accordion',
#  'acid house',
#  'acid jazz',
#  'acid rock',
#  'acid trance',
#  'acousmatic',
#  'acoustic blues',
#  'acoustic pop',
#  'acoustic punk',
#  'adoracion',
#  'adult standards',
#  'adventista',
#  'afghan pop',
#  'afghan traditional',
#  'african gospel',
#  'african percussion',
#  'african reggae',
#  'african rock',
#  'afro dancehall',
#  'afro house',
#  'afro psych',
#  'afro-funk',
#  'afrobeat',
#  'afrobeat brasileiro',
#  'afrofuturism',
#  'afrofuturismo brasileiro',
#  'afropop',
#  'aggrotech',
#  'alabama indie',
#  'alabama metal',
#  'alabama rap',
#  'albanian pop',
#  'alberta country',
#  'album rock',
#  'albuquerque indie',
#  'alt-idol',
#  'alternative americana',
#  'alternative country',
#  'alternative dance',
#  'alternative emo',
#  'alternative hip hop',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168592 entries, 0 to 168591
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                168592 non-null  int64
#  1   acousticness      168592 non-null  float64
#  2   artists           168592 non-null  object
#  3   danceability      168592 non-null  float64
#  4   duration_ms       168592 non-null  int64
#  5   energy            168592 non-null  float64
#  6   explicit          168592 non-null  int64
#  7   id                168592 non-null  object
#  8   instrumentalness  168592 non-null  float64
#  9   key               168592 non-null  int64
#  10  liveness          168592 non-null  float64
#  11  loudness          168592 non-null  float64
#  12  mode              168592 non-null  int64
#  13  name              168592 non-null  object
#  14  popularity        168592 non-null  int64
#  15  release_date      168592 non-null  object
# ...

# %%
sns.heatmap(df.isna())

# %%
df.isna().sum()
# Out:
# Id                  0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
sns.distplot(df['popularity'])

# %%
df['popularity'].value_counts()
# Out:
# 0      25628
# 41      3207
# 44      3159
# 42      3141
# 43      3089
#        ...
# 97         3
# 96         2
# 95         2
# 98         1
# 100        1
# Name: popularity, Length: 100, dtype: int64

# %%
df[df['popularity']==0]
# Out:
#             Id  acousticness  \
# 10          10         0.996
# 11          11         0.982
# 12          12         0.995
# 13          13         0.994
# 14          14         0.990
# ...        ...           ...
# 168525  168525         0.995
# 168526  168526         0.951
# 168527  168527         0.977
# 168528  168528         0.989
# 168560  168560         0.533
#
#                                                   artists  danceability  \
# 10                                    ['Ignacio Corsini']         0.485
# 11                                            ['Fortugé']         0.684
# 12                                  ['Maurice Chevalier']         0.463
# 13                                    ['Ignacio Corsini']         0.378
# 14                                            ['Georgel']         0.315
# ...                                                   ...           ...
# 168525         ['Johann Sebastian Bach', 'Axel Gillison']         0.349
# ...

# %%
sns.jointplot(x=df['popularity'],y=df['duration_ms'])

# %% [markdown]
# Draw a plot of two variables with bivariate and univariate graphs.

# %%
(df['duration_ms'].min()/60)/60
# Out:
# 1.418888888888889

# %%
df['duration_minutes']=df['duration_ms']/60000

# %%
df[df['duration_minutes']==df['duration_minutes'].min()]
# Out:
#           Id  acousticness            artists  danceability  duration_ms  \
# 67028  67028           0.0  ['Sarah Vaughan']           0.0         5108
#
#        energy  explicit                      id  instrumentalness  key  ...  \
# 67028     0.0         0  0hr9kRUi2X4MXc72A4VxG4               0.0    0  ...
#
#        loudness  mode         name popularity  release_date speechiness  \
# 67028     -60.0     0  Pause Track          0          1949         0.0
#
#        tempo  valence  year  duration_minutes
# 67028    0.0      0.0  1949          0.085133
#
# [1 rows x 21 columns]

# %%
df[df['duration_minutes']==df['duration_minutes'].max()]
# Out:
#           Id  acousticness            artists  danceability  duration_ms  \
# 90154  90154         0.111  ['Sound Dreamer']           0.0      5403500
#
#          energy  explicit                      id  instrumentalness  key  ...  \
# 90154  0.000099         0  7foc25ig7dibxvULPU2kBG             0.392    2  ...
#
#        loudness  mode                      name popularity  release_date  \
# 90154   -21.669     1  Brown Noise - 90 Minutes         51    2013-06-05
#
#       speechiness  tempo  valence  year  duration_minutes
# 90154         0.0    0.0      0.0  2013         90.058333
#
# [1 rows x 21 columns]

# %%
df[(df['popularity']>80) & (df['year']==2015)]
# Out:
#         Id  acousticness                          artists  danceability  \
# 9372  9372       0.61200             ['Melanie Martinez']         0.680
# 9373  9373       0.01150                  ['Tame Impala']         0.640
# 9374  9374       0.03710                       ['WILLOW']         0.764
# 9378  9378       0.06710                   ['The Weeknd']         0.585
# 9384  9384       0.04620            ['Twenty One Pilots']         0.734
# 9391  9391       0.00835            ['Twenty One Pilots']         0.645
# 9392  9392       0.36900  ['Wiz Khalifa', 'Charlie Puth']         0.689
# 9395  9395       0.00801    ['Mark Ronson', 'Bruno Mars']         0.856
# 9405  9405       0.83500                ['Justin Bieber']         0.609
#
#       duration_ms  energy  explicit                      id  instrumentalness  \
# 9372       179867   0.729         1  4DpNNXFMMxQEKl7r0ykkWA          0.000000
# 9373       216320   0.740         1  6K4t31amVTZDgR3sKmwUJJ          0.006780
# ...

# %%
plt.figure(figsize=(12,10),constrained_layout=True)
sns.set(style='whitegrid')
corr=df.corr()
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
sns.clustermap(corr,annot=True)

# %%
plt.figure(figsize=(12,10),constrained_layout=True)
sns.barplot(x='name',y='popularity',data=df.nlargest(10,'popularity'))

# %%
df.groupby('name')['popularity'].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-9c17ce951fe8> in <module>
# ----> 1 df.groupby('name')['popularity'].plot.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in attr(*args, **kwargs)
#     331                 return getattr(self.plot, name)(*args, **kwargs)
#     332
# --> 333             return self._groupby.apply(f)
#     334
#     335         return attr
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     222     )
#     223     def apply(self, func, *args, **kwargs):
# --> 224         return super().apply(func, *args, **kwargs)
#     225
#     226     @Substitution(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     733         with option_context("mode.chained_assignment", None):
#     734             try:
# ...

# %%
df.groupby('artists')['popularity'].sum().nlargest(10).plot(kind='bar',cmap='coolwarm')

# %%
df['year']
# Out:
# 0         1921
# 1         1921
# 2         1921
# 3         1921
# 4         1921
#           ...
# 168587    2020
# 168588    2020
# 168589    2020
# 168590    2020
# 168591    2020
# Name: year, Length: 168592, dtype: int64

# %%
sns.lineplot(x=df['year'].value_counts().index,y=df['year'].value_counts())

# %%
df['year'].value_counts()
# Out:
# 1970    2000
# 1975    2000
# 1968    2000
# 1969    2000
# 1971    2000
#         ...
# 1925     263
# 1924     236
# 1923     169
# 1921     128
# 1922      72
# Name: year, Length: 100, dtype: int64

# %%
measure=["acousticness","danceability","energy","speechiness","liveness","valence"]

for clo in measure:
    x=df.groupby('year')[clo].mean()
    ax=sns.lineplot(x=x.index,y=x,label=clo)

# %%
df.groupby('year')['duration_minutes'].mean().plot(kind='line')
